# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749")

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# ### Checking the structure & characteristics of the dataset

# %%
#finding the shape of the dataset
data.shape
# Out:
# (180, 9)

# %%
#Finding the datatypes of the columns
data.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
#Getting the information regarding the count of non-null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#Checking the null values for each column
data.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#Getting the count unique values in each column
data.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %% [markdown]
# ####**Analyzing value counts**

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
data['Product'].value_counts()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
data['Education'].value_counts()
# Out:
# Education
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: count, dtype: int64

# %%
data['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
data['Usage'].value_counts()
# Out:
# Usage
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: count, dtype: int64

# %%
data['Fitness'].value_counts()
# Out:
# Fitness
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: count, dtype: int64

# %%
data['Miles'].value_counts()
# Out:
# Miles
# 85     27
# 95     12
# 66     10
# 75     10
# 47      9
# 106     9
# 94      8
# 113     8
# 53      7
# 100     7
# 180     6
# 200     6
# 56      6
# 64      6
# 127     5
# 160     5
# 42      4
# 150     4
# 38      3
# 74      3
# 170     3
# 120     3
# 103     3
# 132     2
# 141     2
# 280     1
# 260     1
# 300     1
# 240     1
# 112     1
# 212     1
# 80      1
# 140     1
# 21      1
# 169     1
# 188     1
# 360     1
# Name: count, dtype: int64

# %% [markdown]
# ### **Outlier Detection**

# %% [markdown]
# Outliers can be resolved using binning which is used in the following discussion

# %%
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
Num_cols=['Age','Miles','Income']

# %%
for i in Num_cols:
  sns.boxplot(y = data[i])
  plt.yticks(fontsize=10)
  plt.ylabel(f"{i} of the dataset", fontsize=10)
  plt.title(f"{i} of the dataset", fontsize=10)
  plt.show()

# %%
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ### **Univariate Analysis**

# %%
# For categorical variables
cat_cols=['Gender','MaritalStatus','Education','Usage','Fitness','Product']
for i in cat_cols:
  sns.countplot(x=i,data=data)
  plt.show()

# %%
# For Numerical variables
num_cols=['Age','Income','Miles']
for i in num_cols:
  sns.kdeplot(data[i])
  plt.show()

# %% [markdown]
# ###**Bivariate Analysis**

# %%
#Bivariate Analysis fo categorical using values
cat_cols=['Gender','MaritalStatus','Education','Usage','Fitness']
for i in cat_cols:
  sns.countplot(x=i,hue='Product',data=data)
  plt.show()

# %%
#Bivariate Analysis fo categorical using Propotions/Percentage
for i in cat_cols:
   i=pd.crosstab(data[i],data['Product'],normalize='index')
   i.plot(kind='bar')
   plt.show()

# %%
#Bivariate Analysis fo Numerical variables using values
num_cols=['Age','Income','Miles']
for i in num_cols:
  sns.boxplot(x='Product', y=i, data=data)
  plt.xticks(rotation=90,fontsize=12)
  plt.yticks(fontsize=12)
  plt.title(i, fontsize=15)
  plt.show()

# %%
data_copy=data.copy()

# %%
# Binning numerical columns to categorical
bins=[0,30000,40000,50000,60000,70000,80000,90000,120000]
labels=['<30000','30000-40000','40000-50000','50000-60000','60000-70000','70000-80000','80000-90000','>90000']
data['Income_Group']=pd.cut(data['Income'],bins=bins,labels=labels)
data.head()
bins=[0,20,25,30,35,40,51]
labels=['<20','20-25','25-30','30-35','35-40','>40']
data['Age_Group']=pd.cut(data['Age'],bins=bins,labels=labels)
data.head()
bins=[0,20,40,60,80,100,120,150,200,360]
labels=['<20','20-40','40-60','60-80','80-100','100-120','120-150','150-200','>200']
data['Miles_Group']=pd.cut(data['Miles'],bins=bins,labels=labels)
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles Income_Group Age_Group Miles_Group
# 0    112       <30000       <20     100-120
# 1     75  30000-40000       <20       60-80
# 2     66  30000-40000       <20       60-80
# 3     85  30000-40000       <20      80-100
# 4     47  30000-40000       <20       40-60

# %%
#Bivariate Analysis fo Numerical variables using its propotion/percentage
num_cols=['Age_Group','Income_Group','Miles_Group']
for i in num_cols:
   i=pd.crosstab(data[i],data['Product'],normalize='index')
   i.plot(kind='bar')
   plt.show()

# %%
sns.lineplot(x='Age', y='Income', data=data)
plt.show()

sns.scatterplot(x='Age', y='Income', data=data)
plt.show()

# %%
sns.lineplot(x='Age', y='Miles', data=data)
plt.show()

sns.scatterplot(x='Age', y='Miles', data=data)
plt.show()

# %%
sns.lineplot(x='Income', y='Miles', data=data)
plt.show()

sns.scatterplot(x='Income', y='Miles', data=data)
plt.show()

# %% [markdown]
# ###**Multivariate**

# %% [markdown]
# Multivariate analysis of Product on the basis of income.

# %%
data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles', 'Income_Group', 'Age_Group',
#        'Miles_Group'],
#       dtype='object')

# %%
catcols=['Gender','Education','MaritalStatus','Fitness','Usage']

# %%
for i in catcols:
  sns.boxplot(x=i,y='Income',hue='Product',data=data)
  plt.xlabel(i, fontsize=12)
  plt.ylabel('Income', fontsize=12)
  plt.xticks(fontsize=12)
  plt.yticks(fontsize=12)
  plt.title(f'Income based on {i}, Product wise', fontsize=15)
  plt.show()

# %% [markdown]
# Multivariate analysis of Product on the basis of age:

# %%
for i in catcols:
  sns.boxplot(x=i,y='Age',hue='Product',data=data)
  plt.xlabel(i, fontsize=12)
  plt.ylabel('Age', fontsize=12)
  plt.xticks(fontsize=12)
  plt.yticks(fontsize=12)
  plt.title(f'Age based on {i}, Product wise', fontsize=15)
  plt.show()

# %% [markdown]
# Multivariate analysis of Product on the basis of Miles:

# %%
for i in catcols:
  sns.boxplot(x=i,y='Miles',hue='Product',data=data)
  plt.xlabel(i, fontsize=12)
  plt.ylabel('Miles', fontsize=12)
  plt.xticks(fontsize=12)
  plt.yticks(fontsize=12)
  plt.title(f'Miles based on {i}, Product wise', fontsize=15)
  plt.show()

# %%
numcols=['Income','Miles']
for i in numcols:
  sns.scatterplot(x=i, y='Age',hue='Product',data=data)
  plt.xticks(rotation=90,fontsize=15)
  plt.yticks(fontsize=15)
  plt.xlabel(i,fontsize=15)
  plt.ylabel('Age',fontsize=15)
  plt.title(f'{i} based on Age, per Genre', fontsize=15)
  plt.show()

# %%
numcols=['Age','Miles']
for i in numcols:
  sns.scatterplot(x=i, y='Income',hue='Product',data=data)
  plt.xticks(fontsize=15)
  plt.yticks(fontsize=15)
  plt.xlabel(i,fontsize=15)
  plt.ylabel('Income',fontsize=15)
  plt.title(f'{i} based on income, per Genre', fontsize=15)
  plt.show()

# %%
numcols=['Age','Income']
for i in numcols:
  sns.scatterplot(x=i, y='Miles',hue='Product',data=data)
  plt.xticks(rotation=90,fontsize=15)
  plt.yticks(fontsize=15)
  plt.xlabel(i,fontsize=15)
  plt.ylabel('Miles',fontsize=15)
  plt.title(f'{i} based on Miles, per Genre', fontsize=15)
  plt.show()

# %% [markdown]
# ### **Overall Percentage of Products from the given data**

# %%
i=data['Product'].value_counts(normalize=True)

# %%
i.plot(kind='pie',
labels=i.index,
autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ### **Correlation and Heat Map**

# %%
data_copy['Gender'].replace({'Female':0,'Male':1},inplace=True)
data_copy['Product'].replace(['KP281','KP481','KP781'],[0,1,2],inplace=True)
data_copy['MaritalStatus'].replace(['Single','Partnered'],[1,0],inplace=True)

# %%
data_copy.head()
# Out:
#    Product  Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0        0   18       1         14              1      3        4   29562
# 1        0   19       1         15              1      2        3   31836
# 2        0   19       0         14              0      4        3   30699
# 3        0   19       1         12              1      3        3   32973
# 4        0   20       1         13              0      4        2   35247
#
#    Miles
# 0    112
# 1     75
# 2     66
# 3     85
# 4     47

# %%
data_copy.corr()
# Out:
#                 Product       Age    Gender  Education  MaritalStatus  \
# Product        1.000000  0.032225  0.230653   0.495018       0.017602
# Age            0.032225  1.000000  0.027544   0.280496      -0.192152
# Gender         0.230653  0.027544  1.000000   0.094089       0.018836
# Education      0.495018  0.280496  0.094089   1.000000      -0.068569
# MaritalStatus  0.017602 -0.192152  0.018836  -0.068569       1.000000
# Usage          0.537447  0.015064  0.214424   0.395155       0.007786
# Fitness        0.594883  0.061105  0.254609   0.410581       0.050751
# Income         0.624168  0.513414  0.202053   0.625827      -0.150293
# Miles          0.571596  0.036618  0.217869   0.307284      -0.025639
#
#                   Usage   Fitness    Income     Miles
# Product        0.537447  0.594883  0.624168  0.571596
# Age            0.015064  0.061105  0.513414  0.036618
# Gender         0.214424  0.254609  0.202053  0.217869
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_copy.corr(),cmap="Blues",annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x='Income',hue='Gender',data=data)
plt.show()

# %% [markdown]
# ### **Customer Profiling**

# %% [markdown]
# ####**Customer Profiling for KP781**

# %% [markdown]
# #####**Recommendations**
#
# *   People having income greater than 70000
# *   People having income>70000 and Education level >=17
# *   People having income>55000 and Usage days>=4
# *   People having income>65000 and Fitness Level>=3
# *   90% of Customers whose fitness level is 5 use KP781

# %% [markdown]
# ####**Customer Profiling for KP481**

# %% [markdown]
# #####**Recommendations**
#  having income in range 60-70 and uage =3
#
# *   Cutomers having income in range 40000-50000 and usage <= 5
# *   Cutomers having income in range 40000-50000 and fitness in the range 2-5
# *   Cutomers having income in range 45000-60000 and Education Level between 16-18.
# *   Cutomers having income in range 35000-45000 and Education Level between 14.
# *   Cutomers having income in range 35000-45000 and Age > 25

# %% [markdown]
# ####**Customer Profiling for KP281**

# %% [markdown]
# #####**Recommendations**
#  having income in range 60-70 and uage =3
#
# *   Cutomers having income < 70000
# *   Cutomers having usage and fitness in the range 2-4
# *   Cutomers having Education Level < 14
# *   Cutomers having income < 70000 and miles <= 150
# *   Peoples who earns < 55000, Female purchases KP281 more when compared to male

# %% [markdown]
# #**NOTE:**
#
# Recommendations for KP481 & KP281 are almost similar, hence from the data provided they almost follows same pattern.
#
# Therefore by having few more data in future, Recommendations can be improved.
